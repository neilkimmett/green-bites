# %%
import duckdb

# Create the database we'll save our work to and load the extensions we'll need
con = duckdb.connect("conflation.ddb")
con.sql("install spatial")
con.sql("install httpfs")
con.sql("load spatial")
con.sql("load httpfs")

# Load the CSV downloaded from Snowflake
con.sql("CREATE TABLE IF NOT EXISTS scores AS SELECT * FROM read_csv('scores.csv', ignore_errors=True)")

# %% [markdown]
# Download the Overture Places data. There's  a lot going on here, but what we're doing is...
# 1. Create a bounding box around all the Alameda County records
# 2. Get all the places from Overture in that bounding box, with a confidence score > 0.5
# 3. Finally transform these results into a format that matches the Alameda County Data

# %%
con.sql("""
    CREATE TABLE IF NOT EXISTS places AS 

    SELECT 
        id, 
        upper(names['primary']) as Facility_Name, 
        upper(addresses[1]['freeform']) as Address, 
        upper(addresses[1]['locality']) as City, 
        upper(addresses[1]['region']) as State, 
        left(addresses[1]['postcode'], 5) as Zip, 
        geometry, 
        ST_X(geometry) as Longitude,
        ST_Y(geometry) as Latitude,
        categories 
    FROM (
        SELECT * 
        FROM read_parquet('s3://overturemaps-us-west-2/release/2024-09-18.0/theme=places/type=place/*', filename=true, hive_partitioning=1),
             bounding_box
        WHERE addresses[1] IS NOT NULL AND
            bbox.xmin BETWEEN -74.2591 AND -73.7004 AND
            bbox.ymin BETWEEN 40.4774 AND 40.9176 AND
            confidence > 0.5
    );
""")

# %%
con.sql("SELECT * FROM venues WHERE MSA_ID = 1 LIMIT 5").show()
# Out:
# ┌──────────┬────────────────┬────────────┬───────────────────────────────────┬─────────────┬──────────────┬──────────────────────┬──────────┬─────────────────┬─────────────┬────────────┬─────────────────┬─────────┬──────────────────────┬───────────────────────┬─────────────┬───────────────────────┬─────────────────┬────────────────────────┬─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┬───────────────┬───────────────────┬─────────────────┬───────────────┬────────────────────────┬─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┬──────────────┬──────────────┬────────────────┬───────────────────────────────────┬────────────────┬───────────────┬───────────┬─────────┬────────────────────────────────────────────┬───────────┬───────────────────┬───────────────────────┬────────────────────────┬───────┬───────────────────────────┬─────────────────┬─────────┬──────────┬───────────────────────────────────────────────────────────────────────┬────────┬────────────────┬────────────────┬────────────────────┬───────────┬─────────┬─────────────────────────────────┬────────────┬────────────────────────┬─────────────────────────────────────────────────┬──────────────────────┬─────────────────────────┬─────────────────┬──────────────────┬───────────────────────────┬───────────────────┬─────────────┬─────────────┬────────────────────────┬───────────────────┬───────────────────────────┬────────┬─────────────┬──────────────────────────┬───────────┬──────────┬────────────────────┬────────────┬────────────────────┬───────────────────────────┬─────────────────────────┬─────────────────────────┬───────────────────┬────────────────────┬─────────────────┬────────────────┬──────────────────────────┬────────────┬────────────────────────────┬────────────────┬───────────────────────────┬────────────────┬─────────────┬───────────┬────────────────────────┬────────────┬─────────────────────────┬───────────────────────────┬───────┬────────────────────────┬──────────────────┬──────────────┬─────────────────────┬─────────────┬───────────────────┬────────────────┬─────────────────────────────────┬────────────────┬─────────────────┬─────────────────────┬─────────────────────┬───────────────────┬────────────────────────────┬────────────────────────────────────┬────────────────────────┬─────────┬───────────┬────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── ...
# │ VENUE_ID │ VENUE_SUBTITLE │ LOGO_IMAGE │            VENUE_NAME             │ ENTITY_TYPE │ LOGO_FILE_ID │   INSTAGRAM_HANDLE   │ PHOTO_ID │ ORGANIZATION_ID │ OTHER_NOTES │ COUNTRY_ID │ MIN_CLASS_PRICE │   ORG   │ PHOTO_V2_VERTICAL_ID │ STUDIO_DIRECT_ENABLED │ SPOTIFY_URL │ NEIGHBORHOOD_OVERRIDE │ QA_COMPLETED_ON │ UPCOMING_CLASSES_COUNT │                                                                                                                                                                                                                                                                                                                                                    WHAT_TO_BRING                                                                                                                                                                                                                                                                                                                                                    │ GEOCODED_FLAG │ CLASSTIVITY_SCORE │ QA_COMPLETED_BY │ EXPERT_REVIEW │ PHOTO_V2_HORIZONTAL_ID │                                                                                                                          HOW_TO_GET_THERE                                                                                                                           │ BOOKING_LINK │ QA_COMPLETED │ RATINGS_OPTOUT │         SOURCE_VENUE_NAME         │ SOLD_OUT_PRICE │ INDUSTRY_NAME │ EXPERT_ID │  NOTES  │                VENUE_ALIAS                 │ SOURCE_ID │ COUNTS_UPDATED_ON │     SERVICE_TYPES     │ SUGGESTED_ARRIVAL_TIME │ TIER  │        UPDATED_ON         │ PHOTO_LEFT_CROP │ PRO_TIP │ POSITION │                           FACEBOOK_PAGE_URL                           │ MSA_ID │ LOGO_UPLOAD_ID │     SOURCE     │ LAST_ROOT_REDIRECT │ PUBLISHED │ SITE_ID │           TWITTER_URL           │ BASE_PRICE │ SUGGESTED_BOOKING_TIME │                    YELP_URL                     │ MAPONICS_COUNTY_FLAG │ COVER_VIDEO_RESOURCE_ID │ MAX_CLASS_PRICE │     TIMEZONE     │        CREATED_ON         │ LATE_CANCELLATION │ VENUE_SCORE │ LOCATION_ID │ SOURCE_TRANSITION_DATE │ _FIVETRAN_DELETED │     _FIVETRAN_SYNCED      │   ID   │ WINDOW_TIME │ NEEDS_CLASS_INSTRUCTIONS │   TYPE    │ MSA_ID_1 │ WINDOW_DAY_OF_WEEK │ POSITION_1 │ FCF_SCHEDULE_SPOTS │       UPDATED_ON_1        │     BOOKING_WINDOW      │ RESERVABLE_HOURS_BEFORE │ SHARE_UTM_CONTENT │ WINDOW_DAYS_BEFORE │ REQUEST_TO_BOOK │ CONTACT_EMAILS │ ALTERNATE_CONTACT_EMAILS │ VENUE_ID_1 │ LATE_CANCELLATION_DEADLINE │ OUT_OF_NETWORK │       CREATED_ON_1        │ SURVEY_ADDRESS │ ROSTER_SENT │ SELL_HIDE │ LATE_CANCELLATION_TIME │ SURVEY_DOB │ LOGO_FEATURED_UPLOAD_ID │ RESERVABLE_MINUTES_BEFORE │ SPOTS │ WINDOW_PRE_DAYS_BEFORE │ SURVEY_EMERGENCY │ SURVEY_PHONE │ RESERVABLE_DEADLINE │ ACCESS_TYPE │ WINDOW_DAYS_AFTER │ HIDE_IN_SEARCH │ AVAILABLE_FOR_TRIALERS_OVERRIDE │ COST_PER_CLASS │ WINDOW_PRE_TIME │ DISABLE_NEW_CLASSES │ PRE_BUILT_PAGE_LIVE │ DISABLE_SPOT_FILL │ ROSTER_LAST_RESERVATION_ID │ ROSTER_LAST_RESERVATION_ID_PACIFIC │ RESERVATIONS_PER_CYCLE │ ENABLED │ PRE_BUILT │                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               DESCRIPTION                                                                         ...
# │  int64   │    varchar     │  varchar   │              varchar              │   varchar   │    int64     │       varchar        │  int64   │      int64      │   varchar   │   int64    │      int64      │ varchar │        int64         │        boolean        │   varchar   │         int64         │     varchar     │         int64          │                                                                                                                                                                                                                                                                                                                                                       varchar                                                                                                                                                                                                                                                                                                                                                       │    boolean    │      double       │      int64      │    varchar    │         int64          │                                                                                                                               varchar                                                                                                                               │   varchar    │   boolean    │    boolean     │              varchar              │     double     │    varchar    │   int64   │ varchar │                  varchar                   │   int64   │      varchar      │        varchar        │        varchar         │ int64 │          varchar          │     boolean     │ varchar │  int64   │                                varchar                                │ int64  │     int64      │    varchar     │      varchar       │  boolean  │  int64  │             varchar             │   double   │        varchar         │                     varchar                     │       boolean        │         varchar         │      int64      │     varchar      │          varchar          │       time        │   double    │    int64    │          date          │      boolean      │          varchar          │ int64  │    time     │         boolean          │  varchar  │  int64   │      varchar       │   int64    │       int64        │          varchar          │         varchar         │          int64          │      varchar      │       int64        │     boolean     │    varchar     │         varchar          │   int64    │          varchar           │    boolean     │          varchar          │    boolean     │    date     │  boolean  │          time          │  boolean   │          int64          │           int64           │ int64 │         int64          │     boolean      │   boolean    │        time         │   varchar   │       int64       │    boolean     │             boolean             │     int64      │      time       │       boolean       │       boolean       │      boolean      │           int64            │               int64                │         int64          │ boolean │  boolean  │                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 varchar                                                                           ...
# ├──────────┼────────────────┼────────────┼───────────────────────────────────┼─────────────┼──────────────┼──────────────────────┼──────────┼─────────────────┼─────────────┼────────────┼─────────────────┼─────────┼──────────────────────┼───────────────────────┼─────────────┼───────────────────────┼─────────────────┼────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────┼───────────────────┼─────────────────┼───────────────┼────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────┼──────────────┼────────────────┼───────────────────────────────────┼────────────────┼───────────────┼───────────┼─────────┼────────────────────────────────────────────┼───────────┼───────────────────┼───────────────────────┼────────────────────────┼───────┼───────────────────────────┼─────────────────┼─────────┼──────────┼───────────────────────────────────────────────────────────────────────┼────────┼────────────────┼────────────────┼────────────────────┼───────────┼─────────┼─────────────────────────────────┼────────────┼────────────────────────┼─────────────────────────────────────────────────┼──────────────────────┼─────────────────────────┼─────────────────┼──────────────────┼───────────────────────────┼───────────────────┼─────────────┼─────────────┼────────────────────────┼───────────────────┼───────────────────────────┼────────┼─────────────┼──────────────────────────┼───────────┼──────────┼────────────────────┼────────────┼────────────────────┼───────────────────────────┼─────────────────────────┼─────────────────────────┼───────────────────┼────────────────────┼─────────────────┼────────────────┼──────────────────────────┼────────────┼────────────────────────────┼────────────────┼───────────────────────────┼────────────────┼─────────────┼───────────┼────────────────────────┼────────────┼─────────────────────────┼───────────────────────────┼───────┼────────────────────────┼──────────────────┼──────────────┼─────────────────────┼─────────────┼───────────────────┼────────────────┼─────────────────────────────────┼────────────────┼─────────────────┼─────────────────────┼─────────────────────┼───────────────────┼────────────────────────────┼────────────────────────────────────┼────────────────────────┼─────────┼───────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── ...
# │   126753 │ NULL           │ NULL       │ Naturallyou by Terry Conrad, APRN │ VENUE       │         NULL │ naturallyougreenwich │     NULL │          133810 │ NULL        │          1 │            NULL │ NULL    │                 NULL │ false                 │ NULL        │                  NULL │ NULL            │                   NULL │ Please visit the business' website https://www.naturallyou.net/ for information regarding its services, COVID-19 safety precautions, any screening forms, terms of use, waivers, and other information.\n\nWhen you arrive to your appointment, you can get settled into the space and complete any necessary paperwork at the front desk. Please also note that you are requesting a specific appointment slot with an assigned practitioner at Naturallyou by Terry Conrad, APRN, so if you need to cancel your reservation, please do so as early in advance as possible.                                                                                                                                        │ true          │               0.0 │            NULL │ NULL          │                 757200 │ Naturallyou by Terry Conrad, APRN is located at 31 Sawmill Lane, Greenwich CT 06830.                                                                                                                                                                                │ NULL         │ false        │ false          │ Naturallyou by Terry Conrad, APRN │           NULL │ NULL          │      NULL │ NULL    │ naturallyou-by-terry-conrad-aprn-greenwich │    242520 │ NULL              │ [\n  "APPOINTMENT"\n] │ 15 minutes before      │  NULL │ 2021-09-27 14:52:39.000 Z │ NULL            │ NULL    │        1 │ https://www.facebook.com/TerryConradAPRN                              │      1 │           NULL │ MSINVENTORY    │ NULL               │ true      │  242520 │ NULL                            │       NULL │ NULL                   │ NULL                                            │ true                 │ NULL                    │            NULL │ America/New_York │ 2021-09-23 15:49:51.000 Z │ NULL              │         0.0 │           1 │ NULL                   │ false             │ 2024-03-13 20:57:17.102 Z │ 104094 │ 05:00:00    │ false                    │ CLASSPASS │        1 │ NULL               │       NULL │               NULL │ 2021-09-27 14:44:38.000 Z │ Opens 7 Days in Advance │                    NULL │ NULL              │                 14 │ NULL            │ NULL           │ NULL                     │     126753 │ NULL                       │ true           │ 2021-09-23 15:49:51.000 Z │ false          │ NULL        │ false     │ 12:00:00               │ false      │                    NULL │                      2160 │     1 │                   NULL │ false            │ false        │ NULL                │ member      │              NULL │ false          │ NULL                            │           NULL │ NULL            │ false               │ false               │ false             │                       NULL │                               NULL │                     99 │ true    │ false     │ Naturallyou by Terry Conrad, APRN is listed on ClassPass as part of ClassPass Concierge, a program that allows you to request appointments at businesses that are not ClassPass partners. To learn more about Concierge, see https://www.classpass.com/partners/concierge-faqs. To learn more about the business, please visit https://www.naturallyou.net/. \n\nUpon your reservation request, a concierge will attempt to reserve the appointment on your behalf at your preferred time. Actual availability may differ from what is shown. Your reservation will be pending until you receive a confirmation email.\n\nGratuity and additional enhancements are not included in the cost of your reservation. Please remember to tip based on the full amount of the service reserved. Images above that don't have a 'Google' designation are stock photos.\n ...
# │   222592 │ NULL           │ NULL       │ HP Pilates                        │ VENUE       │         NULL │ HallettsPointPilates │     NULL │          221087 │ NULL        │          1 │            NULL │ NULL    │                 NULL │ false                 │ NULL        │                  NULL │ NULL            │                   NULL │ Grab a pair of grippy socks at the door for $3! We also have hair ties ($1) and clips ($3) and leg warmers ($10) for sale -- we accept Cash or Venmo!\n\nStay hydrated (we have filtered water on-site) and have fun!\n                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             │ true          │               0.0 │            NULL │ NULL          │                1309616 │ HP Pilates is located at 9-20 35th Ave, Astoria, Queens, NY 11106\nBetween 9th and 10th street on 35th Avenue (2 blocks off Vernon BLVD)\n\nSlowly type building code *1128\nElevators are up the ramp to your left (Suite 3F -- Pink doors at end of the hallway!) │ NULL         │ false        │ false          │ HP Pilates and Yoga               │           NULL │ NULL          │      NULL │ NULL    │ hp-pilates-queens                          │    222592 │ NULL              │ [\n  "CLASS"\n]       │ 15 minutes before      │  NULL │ 2024-01-22 09:58:14.000 Z │ NULL            │ NULL    │        1 │ NULL                                                                  │      1 │        1309620 │ WELLNESSLIVING │ NULL               │ true      │  506516 │ NULL                            │       NULL │ NULL                   │ https://www.yelp.com/biz/halletts-point-pilates │ true                 │ NULL                    │            NULL │ America/New_York │ 2024-01-22 14:58:14.000 Z │ NULL              │         0.0 │           1 │ NULL                   │ false             │ 2024-09-21 15:57:52.849 Z │ 199927 │ 05:00:00    │ false                    │ CLASSPASS │        1 │ NULL               │       NULL │               NULL │ 2024-01-22 14:58:14.000 Z │ Opens 7 Days in Advance │                    NULL │ NULL              │                  7 │ NULL            │ NULL           │ NULL                     │     222592 │ NULL                       │ false          │ 2024-01-22 14:58:14.000 Z │ false          │ NULL        │ false     │ 00:00:00               │ false      │                    NULL │                         5 │    10 │                   NULL │ false            │ false        │ NULL                │ member      │              NULL │ false          │ NULL                            │           NULL │ NULL            │ false               │ false               │ false             │                       NULL │                               NULL │                     99 │ true    │ false     │ Located at The Cigar Factory, they are bringing wellness and health to the Astoria/LIC area!\n\nTheir business model revolves on the community, with local instructors, daily class offerings and full price transparency. Join them at their new Reformer Pilates Studio to see what all the rave is about.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# │   225296 │ The High Line  │ NULL       │ Berlin Currywurst                 │ VENUE       │         NULL │ berlincurrywurst     │     NULL │          223211 │ NULL        │          1 │            NULL │ NULL    │                 NULL │ false                 │ NULL        │                  NULL │ NULL            │                   NULL │ Your food or drink will be prepared upon arrival once you have checked in with the business. Any additional items or addons will need to be paid for separately outside of the ClassPass app. You will receive an email with pickup instructions before your pickup window. When you arrive, show your confirmation page to confirm your purchase. Once you have shown your confirmation your food will be prepared.\n\nProducts may contain allergens such as milk, gluten, peanuts, tree nuts, eggs, celery, soybeans, sesame, mustard, fish, lupin, mollusks, crustaceans, sulfur dioxide and sulfites. For any questions regarding allergens, please contact the business directly before you place your order. │ true          │               0.0 │            NULL │ NULL          │                1280536 │ Berlin Currywurst - The High Line is located at NKA High Line Park West 15th Street, New York, NY 10011.                                                                                                                                                            │ NULL         │ false        │ false          │ Berlin Currywurst - The High Line │           NULL │ NULL          │      NULL │ NULL    │ berlin-currywurst-the-high-line-new-york   │    536847 │ NULL              │ [\n  "APPOINTMENT"\n] │ 15 minutes before      │  NULL │ 2024-03-12 16:00:51.000 Z │ NULL            │ NULL    │        1 │ https://www.facebook.com/BerlinCurrywurstLA/                          │      1 │        1280534 │ MSINVENTORY    │ NULL               │ true      │  536847 │ https://twitter.com/BerlinCurry │       NULL │ NULL                   │ NULL                                            │ true                 │ NULL                    │            NULL │ America/New_York │ 2024-03-12 16:00:51.000 Z │ NULL              │         0.0 │           1 │ NULL                   │ false             │ 2024-03-13 20:57:22.124 Z │ 202630 │ 05:00:00    │ true                     │ CLASSPASS │        1 │ NULL               │       NULL │               NULL │ 2024-04-01 22:21:21.000 Z │ Opens 7 Days in Advance │                    NULL │ NULL              │                  7 │ NULL            │ NULL           │ NULL                     │     225296 │ NULL                       │ false          │ 2024-03-12 16:00:51.000 Z │ false          │ NULL        │ false     │ 12:00:00               │ false      │                    NULL │                         5 │     1 │                   NULL │ false            │ false        │ NULL                │ member      │              NULL │ false          │ NULL                            │           NULL │ NULL            │ false               │ false               │ false             │                       NULL │                               NULL │                     99 │ true    │ false     │ Your food or drink will be prepared upon arrival once you have checked in with the business. Any additional items or addons will need to be paid for separately outside of the ClassPass app.\n\nHaving grown up in the home country of Currywurst, they decided to share this German cultural treasure with their friends and all the people in LA and NYC who are as curious as they are to discover foreign trends and tastes. \n\nCreated 60 years ago, Currywurst has become the number one street food in Germany. If you ever have the chance to visit Berlin by night, you will feel the magical spirit of those vibrant Currywurst stands on the corner which has become a neighborhood meeting point. \n\nThey do Currywurst the authentic way you get it served on Berlin’s urban sidewalks. Their recipe is steeped in German tradition. Their menu i ...
# │   121959 │ NULL           │ NULL       │ Tantrum Salon & Boutique          │ VENUE       │         NULL │ tantrumstyle         │     NULL │          129185 │ NULL        │          1 │            NULL │ NULL    │                 NULL │ false                 │ NULL        │                  NULL │ NULL            │                   NULL │ Please visit the business' website http://tantrumstyle.com/ for information regarding its services, COVID-19 safety precautions, any screening forms, terms of use, waivers, and other information.\n\nWhen you arrive to your appointment, you can get settled into the space and complete any necessary paperwork at the front desk. Please also note that you are requesting a specific appointment slot with an assigned practitioner at Tantrum Salon & Boutique, so if you need to cancel your reservation, please do so as early in advance as possible.                                                                                                                                                     │ true          │               0.0 │            NULL │ NULL          │                 746872 │ Tantrum Salon & Boutique is located at 650 Union Boulevard, Totowa, NJ 07512.                                                                                                                                                                                       │ NULL         │ false        │ false          │ Tantrum Salon & Boutique          │           NULL │ NULL          │      NULL │ NULL    │ tantrum-salon-and-boutique-totowa          │    237474 │ NULL              │ [\n  "APPOINTMENT"\n] │ 15 minutes before      │  NULL │ 2021-09-01 13:53:41.000 Z │ NULL            │ NULL    │        1 │ https://www.facebook.com/pages/Tantrum-Salon-Boutique/157519310945206 │      1 │           NULL │ MSINVENTORY    │ NULL               │ true      │  237474 │ NULL                            │       NULL │ NULL                   │ NULL                                            │ true                 │ NULL                    │            NULL │ America/New_York │ 2021-08-30 17:01:38.000 Z │ NULL              │         0.0 │           1 │ NULL                   │ false             │ 2024-03-13 20:57:16.841 Z │  99300 │ 05:00:00    │ false                    │ CLASSPASS │        1 │ NULL               │       NULL │               NULL │ 2021-09-01 11:52:27.000 Z │ Opens 7 Days in Advance │                    NULL │ NULL              │                 14 │ NULL            │ NULL           │ NULL                     │     121959 │ NULL                       │ true           │ 2021-08-30 17:01:38.000 Z │ false          │ NULL        │ false     │ 12:00:00               │ false      │                    NULL │                      2160 │     1 │                   NULL │ false            │ false        │ NULL                │ member      │              NULL │ false          │ NULL                            │           NULL │ NULL            │ false               │ false               │ false             │                       NULL │                               NULL │                     99 │ true    │ false     │ Tantrum Salon & Boutique is listed on ClassPass as part of ClassPass Concierge, a program that allows you to request appointments at businesses that are not ClassPass partners. To learn more about Concierge, see https://www.classpass.com/partners/concierge-faqs. To learn more about the business, please visit http://tantrumstyle.com/. \n\nUpon your reservation request, a concierge will attempt to reserve the appointment on your behalf at your preferred time. Actual availability may differ from what is shown. Your reservation will be pending until you receive a confirmation email.\n\nGratuity and additional enhancements are not included in the cost of your reservation. Please remember to tip based on the full amount of the service reserved. Images above that don't have a 'Google' designation are stock photos.\n\nNOTE: If yo ...
# │   133722 │ NULL           │ NULL       │ Haircuts By Jacquelyn             │ VENUE       │         NULL │ NULL                 │     NULL │          140441 │ NULL        │          1 │            NULL │ NULL    │                 NULL │ false                 │ NULL        │                  NULL │ NULL            │                   NULL │ Please visit the business' website for information regarding its services, COVID-19 safety precautions, any screening forms, terms of use, waivers, and other information.\n\nWhen you arrive to your appointment, you can get settled into the space and complete any necessary paperwork at the front desk. Please also note that you are requesting a specific appointment slot with an assigned practitioner at Haircuts By Jacquelyn, so if you need to cancel your reservation, please do so as early in advance as possible.                                                                                                                                                                                 │ true          │               0.0 │            NULL │ NULL          │                 786376 │ Haircuts By Jacquelyn is located at 1 11th Avenue Unit D-4, Shalimar FL 32579.                                                                                                                                                                                      │ NULL         │ false        │ false          │ Haircuts By Jacquelyn             │           NULL │ NULL          │      NULL │ NULL    │ haircuts-by-jacquelyn-shalimar             │    249811 │ NULL              │ [\n  "APPOINTMENT"\n] │ 15 minutes before      │  NULL │ 2021-11-12 17:09:27.000 Z │ NULL            │ NULL    │        1 │ https://www.facebook.com/haircutsbyjacquelyn/                         │      1 │           NULL │ MSINVENTORY    │ NULL               │ true      │  249811 │ NULL                            │       NULL │ NULL                   │ NULL                                            │ true                 │ NULL                    │            NULL │ America/New_York │ 2021-10-21 19:23:43.000 Z │ NULL              │         0.0 │           1 │ NULL                   │ false             │ 2024-03-13 20:57:17.507 Z │ 111063 │ 05:00:00    │ false                    │ CLASSPASS │        1 │ NULL               │       NULL │               NULL │ 2021-11-12 16:59:00.000 Z │ Opens 7 Days in Advance │                    NULL │ NULL              │                  7 │ NULL            │ NULL           │ NULL                     │     133722 │ NULL                       │ true           │ 2021-10-21 19:23:43.000 Z │ false          │ NULL        │ false     │ 12:00:00               │ false      │                    NULL │                      2160 │     1 │                   NULL │ false            │ false        │ NULL                │ member      │              NULL │ false          │ NULL                            │           NULL │ NULL            │ false               │ false               │ false             │                       NULL │                               NULL │                     99 │ true    │ false     │ Haircuts By Jacquelyn is listed on ClassPass as part of ClassPass Concierge, a program that allows you to request appointments at businesses that are not ClassPass partners. To learn more about Concierge, see https://www.classpass.com/partners/concierge-faqs. To learn more about the business, please visit its website. \n\nUpon your reservation request, a concierge will attempt to reserve the appointment on your behalf at your preferred time. Actual availability may differ from what is shown. Your reservation will be pending until you receive a confirmation email.\n\nGratuity and additional enhancements are not included in the cost of your reservation. Please remember to tip based on the full amount of the service reserved. Images above that don't have a 'Google' designation are stock photos.\n\nNOTE: If you are a business ...
# └──────────┴────────────────┴────────────┴───────────────────────────────────┴─────────────┴──────────────┴──────────────────────┴──────────┴─────────────────┴─────────────┴────────────┴─────────────────┴─────────┴──────────────────────┴───────────────────────┴─────────────┴───────────────────────┴─────────────────┴────────────────────────┴─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┴───────────────┴───────────────────┴─────────────────┴───────────────┴────────────────────────┴─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┴──────────────┴──────────────┴────────────────┴───────────────────────────────────┴────────────────┴───────────────┴───────────┴─────────┴────────────────────────────────────────────┴───────────┴───────────────────┴───────────────────────┴────────────────────────┴───────┴───────────────────────────┴─────────────────┴─────────┴──────────┴───────────────────────────────────────────────────────────────────────┴────────┴────────────────┴────────────────┴────────────────────┴───────────┴─────────┴─────────────────────────────────┴────────────┴────────────────────────┴─────────────────────────────────────────────────┴──────────────────────┴─────────────────────────┴─────────────────┴──────────────────┴───────────────────────────┴───────────────────┴─────────────┴─────────────┴────────────────────────┴───────────────────┴───────────────────────────┴────────┴─────────────┴──────────────────────────┴───────────┴──────────┴────────────────────┴────────────┴────────────────────┴───────────────────────────┴─────────────────────────┴─────────────────────────┴───────────────────┴────────────────────┴─────────────────┴────────────────┴──────────────────────────┴────────────┴────────────────────────────┴────────────────┴───────────────────────────┴────────────────┴─────────────┴───────────┴────────────────────────┴────────────┴─────────────────────────┴───────────────────────────┴───────┴────────────────────────┴──────────────────┴──────────────┴─────────────────────┴─────────────┴───────────────────┴────────────────┴─────────────────────────────────┴────────────────┴─────────────────┴─────────────────────┴─────────────────────┴───────────────────┴────────────────────────────┴────────────────────────────────────┴────────────────────────┴─────────┴───────────┴────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── ...

# %%
total_venues_sql = con.sql("SELECT count(*) FROM venues WHERE MSA_ID = 1 and ENABLED = 1")
total_venues = total_venues_sql.fetchone()[0]
total_venues_sql.show()
# Out:
# ┌──────────────┐
# │ count_star() │
# │    int64     │
# ├──────────────┤
# │         6256 │
# └──────────────┘

# %%
con.sql("SELECT * FROM places LIMIT 5 WHERE categories.primary IN ('eat_and_drink', 'restaurant')").show()
# Out:
# ┌──────────────────────────────────┬──────────────────────────────────────┬─────────────────┬───────────────┬─────────┬─────────┬─────────────────────────────────┬──────────────┬────────────┬───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┬────────────────────┬───────────────────────────────────────────┐
# │                id                │            Facility_Name             │     Address     │     City      │  State  │   Zip   │            geometry             │  Longitude   │  Latitude  │                                                      categories                                                       │         h3         │               full_address                │
# │             varchar              │               varchar                │     varchar     │    varchar    │ varchar │ varchar │            geometry             │    double    │   double   │                                    struct("primary" varchar, alternate varchar[])                                     │       uint64       │                  varchar                  │
# ├──────────────────────────────────┼──────────────────────────────────────┼─────────────────┼───────────────┼─────────┼─────────┼─────────────────────────────────┼──────────────┼────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────┼───────────────────────────────────────────┤
# │ 08f29115607362d50324fa1377735427 │ TECHCRUNCH                           │ 410 TOWNSEND ST │ SAN FRANCISCO │ CA      │ 94107   │ POINT (-121.640625 33.7243397)  │  -121.640625 │ 33.7243397 │ {'primary': information_technology_company, 'alternate': [b2b_science_and_technology, broadcasting_media_production]} │ 608708420656168959 │ 410 TOWNSEND ST, SAN FRANCISCO, CA, 94107 │
# │ 08f29102982e2612033ac48c8811114b │ ESSAYPOP                             │ NULL            │ LOS ANGELES   │ CA      │ NULL    │ POINT (-120.9375 33.7243397)    │    -120.9375 │ 33.7243397 │ {'primary': middle_school, 'alternate': NULL}                                                                         │ 608708339991314431 │ LOS ANGELES, CA                           │
# │ 08f29102982e26120376a514eaeeff24 │ COOKIES, THEN MILK LACTATION COOKIES │ NULL            │ HELENDALE     │ CA      │ NULL    │ POINT (-120.9375 33.7243397)    │    -120.9375 │ 33.7243397 │ NULL                                                                                                                  │ 608708339991314431 │ HELENDALE, CA                             │
# │ 08f2912b51620832036e8c9b67a4f8d9 │ CARLUCCE INC.                        │ NULL            │ LOS ANGELES   │ CA      │ NULL    │ POINT (-120.234375 33.7243397)  │  -120.234375 │ 33.7243397 │ {'primary': beauty_and_spa, 'alternate': NULL}                                                                        │ 608708514893791231 │ LOS ANGELES, CA                           │
# │ 08f2912b90069c090314e2e0220d252b │ ANGEL'S FURRY FRIENDS RESCUE         │ NULL            │ SAN JOSE      │ CA      │ NULL    │ POINT (-119.8828125 33.7243397) │ -119.8828125 │ 33.7243397 │ {'primary': pet_adoption, 'alternate': [community_services_non_profits, animal_shelter]}                              │ 608708515950755839 │ SAN JOSE, CA                              │
# └──────────────────────────────────┴──────────────────────────────────────┴─────────────────┴───────────────┴─────────┴─────────┴─────────────────────────────────┴──────────────┴────────────┴───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┴────────────────────┴───────────────────────────────────────────┘

# %%
con.sql("""
        SELECT 'venues' as table_name, COUNT(*) as row_count FROM venues
    UNION ALL
    SELECT 'places' as table_name, COUNT(*) as row_count FROM places
        """).show()
# Out:
# ┌────────────┬───────────┐
# │ table_name │ row_count │
# │  varchar   │   int64   │
# ├────────────┼───────────┤
# │ venues     │     93176 │
# │ places     │   6987614 │
# └────────────┴───────────┘

# %%
con.sql("INSTALL h3 FROM community")
con.sql("LOAD h3")

# Add H3 indexs to each table
con.sql("ALTER TABLE places ADD COLUMN IF NOT EXISTS h3 uint64")
con.sql("ALTER TABLE venues ADD COLUMN IF NOT EXISTS h3 uint64")
con.sql("UPDATE places SET h3 = h3_latlng_to_cell(Latitude, Longitude, 7)")
con.sql("UPDATE venues SET h3 = h3_latlng_to_cell(GEOGRAPHY_LAT, GEOGRAPHY_LON, 7)")

# %%
exact_name_match_df = con.sql("""
SELECT
    v.VENUE_ID as vid, p.id as gers, v.VENUE_NAME as v_name, p.Facility_Name as p_name, v.NAME, p.Address
FROM (
    SELECT DISTINCT VENUE_NAME, VENUE_ID, NAME, h3
    FROM venues WHERE MSA_ID = 1
) v
JOIN places p
    ON v.h3 = p.h3
    AND v.VENUE_NAME = p.Facility_Name
""").df()

# %%
exact_name_match_df.head()
# Out:
#       vid                              gers                        v_name  \
# 0  229871  08f2a1008b95aacd033f8966f1a07c60                      SANDWELL
# 1   83481  08f2a1008cb459a803adb6108d067eae              ASKEYA BY MARION
# 2  112734  08f2a10083a5bc400373c48fcaa89b7d        LUXURY NAIL HAIR & SPA
# 3  140283  08f2a10010ca00c20372a28f6ac610fb  YOUR IMAGE BEAUTY PALACE LLC
# 4  186432  08f2a1018a8033aa03a3b92e03508fc4               MVP BARBER SHOP
#
#                          p_name  \
# 0                      SANDWELL
# 1              ASKEYA BY MARION
# 2        LUXURY NAIL HAIR & SPA
# 3  YOUR IMAGE BEAUTY PALACE LLC
# 4               MVP BARBER SHOP
#
#                                                 NAME  \
# 0         412 Amsterdam Ave, New York, NY 10024, USA
# 1  2276 Adam Clayton Powell Jr Blvd, New York, NY...
# 2         600 Bergen Blvd, Ridgefield, NJ 07657, USA
# 3               688 E 219th St, Bronx, NY 10467, USA
# 4            24 Palisade Ave, Yonkers, NY 10701, USA
#
#                             Address
# 0                 412 AMSTERDAM AVE
# 1  2276 ADAM CLAYTON POWELL JR BLVD
# 2                   600 BERGEN BLVD
# 3                    688 E 219TH ST
# 4                   24 PALISADE AVE

# %%
total_venues = con.sql("SELECT count(*) FROM venues WHERE MSA_ID = 1").fetchone()[0]
exact_name_match_rate = exact_name_match_df.shape[0] / total_venues
print(f"Exact name match rate: {exact_name_match_rate:.2%}")
# Out:
# Exact name match rate: 1.29%

# %%
con.sql("""
ALTER TABLE places ADD COLUMN IF NOT EXISTS full_address VARCHAR;

UPDATE places 
SET full_address = TRIM(CONCAT_WS(', ', 
    NULLIF(Address, ''),
    NULLIF(City, ''),
    NULLIF(State, ''),
    NULLIF(Zip, '')
));
""")

# %%
import matplotlib.pyplot as plt

df = con.sql("""
    SELECT
        v.VENUE_ID as vid, p.id as gers, v.VENUE_NAME as v_name, p.Facility_Name as p_name, upper(v.NAME) as v_Address, p.full_address, jaro_winkler_similarity(v_Address, full_address) as similarity
    FROM (
        SELECT DISTINCT VENUE_NAME, VENUE_ID, NAME, h3
        FROM venues
    ) v
    JOIN places p
        ON v.h3 = p.h3
        AND v.VENUE_NAME = p.Facility_Name
    """).df()

# Visualize the distribution of Jaro-Winkler Similarity (jws) scores
plt.figure(figsize=(10, 4))
plt.hist(df['similarity'], bins=40, color='blue', edgecolor='black')
plt.title('Distribution of Jaro-Winkler Similarity Scores')
plt.xlabel('Jaro-Winkler Similarity of Addresses')
plt.ylabel('Frequency')
plt.show()

# %%
exact_name_match_df = con.sql("""
SELECT
    v.VENUE_ID as vid, p.id as gers, v.VENUE_NAME as v_name, p.Facility_Name as p_name, v.NAME, 
        p.full_address
FROM (
    SELECT DISTINCT VENUE_NAME, VENUE_ID, NAME, h3
    FROM venues WHERE MSA_ID = 1
) v
JOIN places p
    ON v.h3 = p.h3
    AND v.VENUE_NAME = p.Facility_Name
    AND jaro_winkler_similarity(upper(v.NAME), upper(p.full_address)) > 0.8
""").df()
display(exact_name_match_df)

exact_name_match_rate = exact_name_match_df.shape[0] / total_venues
display(f"Exact name match rate: {exact_name_match_rate:.2%}")
# Out:
#        vid                              gers                     v_name  \
# 0   113019  08f2a1064ac2cd6e03b40d8c4a86eb61      BLISS NAILS AND SALON
# 1   180922  08f2a13913da0320030fdbbeb3c29fc6      ELEVEN ELEVEN THERAPY
# 2   121386  08f2a1061ac510c3031bedfcb4f07b5e                D'AJE SALON
# 3   177180  08f2a106b234d12e03e6c8a533988918       NYX & HEMERA DAY SPA
# 4   194161  08f2a107903160e203cd3ac73d4b96fa                  C SEA SPA
# ..     ...                               ...                        ...
# 65  216741  08f2a1006138d79503f1dc170b02b881                        AKT
# 66  185776  08f2a10a9cc92d80033a9847cdabcfa2             SO HAIR STUDIO
# 67   42029  08f2a1046d15b17603af941ed4cfa3b6                    UFC GYM
# 68  123323  08f2a1009bad85900368fda8b1c71bd4           PARIS NAIL SALON
# 69  173776  08f2a10094a26a9403505d3b2f62df66  JEAN MICHEL'S LET'S DANCE
#
#                        p_name  \
# 0       BLISS NAILS AND SALON
# 1       ELEVEN ELEVEN THERAPY
# 2                 D'AJE SALON
# 3        NYX & HEMERA DAY SPA
# 4                   C SEA SPA
# ..                        ...
# 65                        AKT
# 66             SO HAIR STUDIO
# 67                    UFC GYM
# 68           PARIS NAIL SALON
# 69  JEAN MICHEL'S LET'S DANCE
#
#                                                  NAME  \
# 0          90 Leonardville Rd, Belford, NJ 07718, USA
# 1               211 Broad St, Red Bank, NJ 07701, USA
# 2               85 Main St, Woodbridge, NJ 07095, USA
# 3    591 Somerset St, North Plainfield, NJ 07060, USA
# 4          516 Morris Ave #518, Summit, NJ 07901, USA
# ..                                                ...
# 65       1256 Old Country Rd, Westbury, NY 11590, USA
# 66  3256 Hempstead Turnpike, Levittown, NY 11756, USA
# 67           85 NJ-17, East Rutherford, NJ 07073, USA
# 68    1273 Paterson Plank Rd, Secaucus, NJ 07094, USA
# 69             275 Main St, Hackensack, NJ 07601, USA
#
#                                     full_address
# 0         90 LEONARDVILLE RD, BELFORD, NJ, 07718
# 1              211 BROAD ST, RED BANK, NJ, 07701
# 2              85 MAIN ST, WOODBRIDGE, NJ, 07095
# 3   591 SOMERSET ST, NORTH PLAINFIELD, NJ, 07060
# 4              516 MORRIS AVE, SUMMIT, NJ, 07901
# ..                                           ...
# 65      1260 OLD COUNTRY RD, WESTBURY, NY, 11590
# 66     3256 HEMPSTEAD TPKE, LEVITTOWN, NY, 11756
# 67    85 STATE RT 17, EAST RUTHERFORD, NJ, 07073
# 68   1273 PATERSON PLANK RD, SECAUCUS, NJ, 07094
# 69            275 MAIN ST, HACKENSACK, NJ, 07601
#
# [70 rows x 6 columns]
# 'Exact name match rate: 1.12%'

# %%
import ollama

def get_embedding(text):
    return ollama.embeddings(
        model='mxbai-embed-large', 
        prompt=text
    )['embedding']

venues_df = con.sql("""
SELECT VENUE_ID as vid, concat(VENUE_NAME, ',', NAME) as description FROM venues WHERE MSA_ID = 1 GROUP BY 2, 1
""").df()
places_df = con.sql("""
SELECT id as gers, concat(Facility_Name, ',', full_address, ',', City, ',', Zip) as description FROM places GROUP BY description, gers
""").df()


# # Compute the embeddings
venues_df['embedding'] = venues_df['description'].apply(lambda x: get_embedding(x))
# places_df['embedding'] = places_df['description'].apply(lambda x: get_embedding(x))

# %%
places_df = con.sql("""
SELECT id as gers, concat(Facility_Name, ',', full_address, ',', City, ',', State, ',', Zip) as description FROM places WHERE State = 'NY' GROUP BY description, gers
""").df()


# # Compute the embeddings
places_df['embedding'] = places_df['description'].apply(lambda x: get_embedding(x))

# %%
venues_df['h3'] = venues_df['vid'].apply(lambda x: con.sql("SELECT h3 from venues WHERE VENUE_ID = " + str(x)))

# %%
# Fix for getting h3 values
places_df['h3'] = places_df['gers'].apply(lambda x: con.sql(f"SELECT h3 from places WHERE id = '{x}'").fetchone()[0])

# %%
venues_df['h3'] = venues_df['vid'].apply(lambda x: con.sql(f"SELECT h3 from venues WHERE VENUE_ID = {x}").fetchone()[0])

# %%
from sentence_transformers.util import cos_sim
import numpy as np
import pandas as pd

def generate_search_embedding(text):
    return ollama.embeddings(
        model='mxbai-embed-large', 
        prompt=text
    )['embedding']

results_df = pd.DataFrame(columns=['v_description', 'p_description', 'vid', 'gers', 'h3', 'similarity_score'])
for index, row in venues_df.iterrows():
    # Generate the candidate embeddings
    print(row['h3'])


    print("venues_df h3 type:", venues_df['h3'].dtype)
    print("places_df h3 type:", places_df['h3'].dtype)

    # Convert to same type (example - adjust based on what we find)
    venues_df['h3'] = venues_df['h3'].astype('uint64')
    places_df['h3'] = places_df['h3'].astype('uint64')


    candidate_places = places_df[places_df['h3'] == row['h3']]

    # Debug: print number of candidates found
    print(f"Found {len(candidate_places)} candidates for h3 {row['h3']}")
    
    # Skip if no candidates found
    if len(candidate_places) == 0:
        print(f"Skipping venue {row['vid']} - no candidates found")
        continue

    sims = cos_sim(row['embedding'], candidate_places['embedding'].tolist())
    
    # Find the highest ranking score and the associated row
    max_sim_index = sims.argmax().item()
    max_sim_score = sims[0][max_sim_index].item()
    highest_ranking_row = candidate_places.iloc[max_sim_index]

    # Print the results
    # Add results to the new DataFrame
    new_row = pd.DataFrame({
        'v_description': row['description'],
        'p_description': highest_ranking_row['description'],
        'vid': row['vid'],
        'gers': highest_ranking_row['gers'],
        'h3': row['h3'],
        'similarity_score': max_sim_score
    }, index=[index])
    results_df = pd.concat([results_df, new_row], ignore_index=True)

results_df
# Out:
# 608725949323673599
# venues_df h3 type: uint64
# places_df h3 type: uint64
# Found 0 candidates for h3 608725949323673599
# Skipping venue 122190 - no candidates found
# 608726166169190399
# venues_df h3 type: uint64
# places_df h3 type: uint64
# Found 0 candidates for h3 608726166169190399
# Skipping venue 121557 - no candidates found
# 608725922312355839
# venues_df h3 type: uint64
# places_df h3 type: uint64
# Found 362 candidates for h3 608725922312355839
# 608725951773147135
# venues_df h3 type: uint64
# places_df h3 type: uint64
# Found 6530 candidates for h3 608725951773147135
# /var/folders/cm/6dp7fzsx6nb7c3l30dks_c_m0000gp/T/ipykernel_6249/3145778950.py:52: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, new_row], ignore_index=True)
# 608725951840255999
# venues_df h3 type: uint64
# places_df h3 type: uint64
# Found 10988 candidates for h3 608725951840255999
# 608725943250321407
# venues_df h3 type: uint64
# places_df h3 type: uint64
# Found 197 candidates for h3 608725943250321407
# 608725952729448447
# venues_df h3 type: uint64
# places_df h3 type: uint64
# Found 462 candidates for h3 608725952729448447
# 608725924342398975
# venues_df h3 type: uint64
# places_df h3 type: uint64
# Found 1657 candidates for h3 608725924342398975
# 608725951873810431
# venues_df h3 type: uint64
# places_df h3 type: uint64
# Found 17 candidates for h3 608725951873810431
# 608725924560502783
# venues_df h3 type: uint64
# places_df h3 type: uint64
# Found 21040 candidates for h3 608725924560502783
# 608725951773147135
# venues_df h3 type: uint64
# places_df h3 type: uint64
# Found 6530 candidates for h3 608725951773147135
# 608725943954964479
# venues_df h3 type: uint64
# places_df h3 type: uint64
# Found 0 candidates for h3 608725943954964479
# Skipping venue 191288 - no candidates found
# 608725924560502783
# venues_df h3 type: uint64
# places_df h3 type: uint64
# Found 21040 candidates for h3 608725924560502783
# 608725924745052159
# venues_df h3 type: uint64
# places_df h3 type: uint64
# Found 1102 candidates for h3 608725924745052159
# 608725924560502783
# venues_df h3 type: uint64
# places_df h3 type: uint64
# Found 21040 candidates for h3 608725924560502783
# 608725951840255999
# venues_df h3 type: uint64
# places_df h3 type: uint64
# Found 10988 candidates for h3 608725951840255999
# 608725951185944575
# venues_df h3 type: uint64
# places_df h3 type: uint64
# Found 6 candidates for h3 608725951185944575
# 608725970832064511
# venues_df h3 type: uint64
# places_df h3 type: uint64
# Found
# 0     08f2a1004c50e16203f97412a6a2b43c  608725922312355839          0.970360
# 1     08f2a1072815a498030ab4ea86fe558e  608725951773147135          0.789204
# 2     08f2a1072c14d92d0384f9dd31553ce2  608725951840255999          0.923261
# 3     08f2a1052c854cd0031028720d9a6b4b  608725943250321407          0.908215
# 4     08f2a1076cd868f403533dec787d33c3  608725952729448447          0.718869
# ...                                ...                 ...               ...
# 5161  08f2a100d51a81620306b4f359967350  608725924610834431          0.698196
# 5162  08f2a100db02a87303865d48479b574c  608725924711497727          0.928018
# 5163  08f2a1008bad568203b371ae10b13b5c  608725923369320447          0.985815
# 5164  08f2a100ab4899b203925079f13d260b  608725923906191359          0.780595
# 5165  08f2a100890f1dad03d33dd07a41324f  608725923335766015          0.986147
#
# [5166 rows x 6 columns]

# %%
# Visualize the distribution of Jaro-Winkler Similarity (jws) scores
plt.figure(figsize=(10, 4))
plt.hist(results_df['similarity_score'], bins=40, color='blue', edgecolor='black')
plt.title('Distribution of Similarity Scores')
plt.xlabel('Similarity of Venues to Places')
plt.ylabel('Frequency')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sort similarity scores in descending order
sorted_scores = np.sort(results_df['similarity_score'])[::-1]
cumulative_venues = np.arange(1, len(sorted_scores) + 1)

# Create the plot
plt.figure(figsize=(12, 6))
plt.plot(sorted_scores, cumulative_venues)
plt.grid(True)
plt.title('Cumulative Distribution of Similarity Scores')
plt.xlabel('Similarity Score')
plt.ylabel('Number of Venues')

# Add some threshold lines for reference
plt.axvline(x=0.9, color='r', linestyle='--', alpha=0.3)
plt.axvline(x=0.8, color='r', linestyle='--', alpha=0.3)

# Create a table with specific thresholds
thresholds = [1.0, 0.99, 0.98, 0.97, 0.96, 0.95, 0.94, 0.93, 0.92, 0.91, 0.90, 0.89, 0.88, 0.87, 0.86, 0.85, 0.84, 0.83, 0.82, 0.81, 0.80]
stats = []
for threshold in thresholds:
    count = (results_df['similarity_score'] >= threshold).sum()
    percentage = (count / len(results_df)) * 100
    stats.append({
        'Threshold': threshold,
        'Venues': count,
        'Percentage': f"{percentage:.1f}%"
    })

print(pd.DataFrame(stats))

plt.show()
# Out:
#     Threshold  Venues Percentage
# 0        1.00       0       0.0%
# 1        0.99     211       4.1%
# 2        0.98     952      18.4%
# 3        0.97    1195      23.1%
# 4        0.96    1373      26.6%
# 5        0.95    1536      29.7%
# 6        0.94    1713      33.2%
# 7        0.93    1843      35.7%
# 8        0.92    1940      37.6%
# 9        0.91    2027      39.2%
# 10       0.90    2135      41.3%
# 11       0.89    2221      43.0%
# 12       0.88    2304      44.6%
# 13       0.87    2370      45.9%
# 14       0.86    2428      47.0%
# 15       0.85    2504      48.5%
# 16       0.84    2593      50.2%
# 17       0.83    2701      52.3%
# 18       0.82    2823      54.6%
# 19       0.81    2946      57.0%
# 20       0.80    3091      59.8%

# %%
results_df.to_csv('venue_place_matches.csv', index=False)

# %%
results_df['primary_category'] = results_df['gers'].apply(
    lambda x: con.sql(f"SELECT categories['primary'] FROM places WHERE id = '{x}'").fetchone()[0]
)
results_df['alternate_categories'] = results_df['gers'].apply(
    lambda x: con.sql(f"SELECT categories['alternate'] FROM places WHERE id = '{x}'").fetchone()[0]
)

# Save updated results
results_df.to_csv('venue_place_matches.csv', index=False)
